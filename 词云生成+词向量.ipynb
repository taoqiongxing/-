# %%
import jieba
from os import path  #用来获取文档的路径

# %%
#词云
from PIL import Image
import numpy as  np
import matplotlib.pyplot as plt
#词云生成工具
from wordcloud import WordCloud,ImageColorGenerator
#需要对中文进行处理
import matplotlib.font_manager as fm

# %%
#背景图
bg=np.array(Image.open("C:/Users/Ax/Desktop/111111/3.jpg"))

# %%
#获取当前的项目文件加的路径
d=path.dirname('C:/Users/Ax/Desktop/111111/')

# %%
#读取停用词表
#stopwords_path='C:/Users/Ax/Desktop/111111/stopwords.txt'

# %%
#添加需要自定以的分词  
def addwordslist(filepath):  
    addwords = [line.strip() for line in open(filepath,encoding="utf8").readlines()]  
    return addwords 

addwords = addwordslist('C:/Users/Ax/Desktop/111111/companyname2.txt')
for word in addwords:
    jieba.add_word(word, tag="companyname", freq =1000000000000)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Ax\AppData\Local\Temp\jieba.cache
# Loading model cost 0.588 seconds.
# Prefix dict has been built succesfully.

# %%
from jieba import posseg
#pos = list(jieba.posseg.cut("南方"))

# %%
#pos = list(jieba.posseg.cut("食品"))
#pos

# %%
#jieba.suggest_freq(("食品"), True)

# %%
#读取要分析的文本
text_path="test_50.txt"

# %%
#读取要分析的文本，读取格式
text=open(path.join(d,text_path),encoding="utf8").read()

# %%
text
# Out:
# '\ufeff关于征求《水产养殖污染防治技术政策》（征求意见稿）意见的函(环办函[2013]1513号)\t\u3000\u3000各有关单位： \xa0 \u3000\u3000为贯彻《 中华人民共和国环境保护法》，防治环境污染，改善环境质量，我部决定制定《 水产养殖污染防治技术政策》。目前，编制单位已完成该文件的 征求意见稿及编制说明，现印送你们，请研究并提出书面意见，于2014年1月15日前反馈我部。 \xa0 \u3000\u3000联系人： 环境保护部科技标准司\u3000刘睿倩 \xa0 \u3000\u3000通信地址：北京市西城区西直门内南小街115号 \xa0 \u3000\u3000邮政编码：100035 \xa0 \u3000\u3000联系电话：（010）66556217 \xa0 \u3000\u3000传真：（010）66556218 \xa0 \u3000\u3000附件：1.征求意见单位名单 \xa0 \u3000\u30002.水产养殖污染防治技术政策（征求意见稿） \xa0 \u3000\u30003. \xa0 水产养殖污染防治技术政策（征求意见稿）编制说明 \xa0 \u3000\u3000环境保护部办公厅 \xa0 \u3000\u30002013年12月19日 \xa0 \u3000\u3000附件1 \xa0 \u3000\u3000征求意见单位名单 \xa0 \u3000\u30001．发展改革委办公厅 \xa0 \u3000\u30002．科技部办公厅 \xa0 \u3000\u30003．农业部办公厅 \xa0 \u3000\u30004．各省、自治区、直辖市环境保护厅（局） \xa0 \u3000\u30005．中国科学院 \xa0 \u3000\u30006．中国工程院 \xa0 \u3000\u30007．中国环境科学研究院 \xa0 \u3000\u30008．中国环境监测总站 \xa0 \u3000\u30009．环境保护部环境发展中心 \xa0 \u3000\u300010．环境保护部环境保护对外合作中心 \xa0 \u3000\u300011．环境保护部南京环境科学研究所 \xa0 \u3000\u300012．环境保护部华南环境科学研究所 \xa0 \u3000\u300013．环境保护部环境规
 \xa0 \u3000\u3000联系电话：（010）66556217 \xa0 \u3000\u3000传真：（010）66556218 \xa0 \u3000\u3000附件：1.征求意见单位名单 \xa0 \u3000\u30002.水产养殖污染防治技术政策（征求意见稿） \xa0 \u3000\u30003. \xa0 水产养殖污染防治技术政策（征求意见稿）编制说明 \xa0 \u3000\u3000环境保护部办公厅 \xa0 \u3000\u30002013年12月19日 \xa0 \u3000\u3000附件1 \xa0 \u3000\u3000征求意见单位名单 \xa0 \u3000\u30001．发展改革委办公厅 \xa0 \u3000\u30002．科技部办公厅 \xa0 \u3000\u30003．农业部办公厅 \xa0 \u3000\u30004．各省、自治区、直辖市环境保护厅（局） \xa0 \u3000\u30005．中国科学院 \xa0 \u3000\u30006．中国工程院 \xa0 \u3000\u30007．中国环境科学研究院 \xa0 \u3000\u30008．中国环境监测总站 \xa0 \u3000\u30009．环境保护部环境发展中心 \xa0 \u3000\u300010．环境保护部环境保护对外合作中心 \xa0 \u3000\u300011．环境保护部南京环境科学研究所 \xa0 \u3000\u300012．环境保护部华南环境科学研究所 \xa0 \u3000\u300013．环境保护部环境规
# ...

# %%
import re
# 创建停用词list  
def stopwordslist(filepath):  
    stopwords = [line.strip() for line in open(filepath,encoding="utf8").readlines()]  
    return stopwords 

def dt_remove(data):
    pattern = u'[a-zA-Z0-9]+'
    wd_length = len(re.findall(pattern,data))
    return wd_length

#定义个函数式用于分词
def jiebaclearText(text):
    #定义一个空的列表，将去除的停用词的分词保存
    mywordList=[]
    #进行分词
    seg_list=jieba.cut(text,cut_all=False)
    #将一个generator的内容用/连接
    listStr='/'.join(seg_list)
    
    sentence_seged = posseg.cut(text.strip())  
    #for word in sentence_seged:
     #   if word.flag=="companyname":
      #      print(word)
    sentence_seged = jieba.cut(text.strip())
    stopwords = stopwordslist('C:/Users/Ax/Desktop/111111/stopwords.txt')  # 这里加载停用词的路径  
    #print(stopwords)
    outstr = ''
        
    for word in sentence_seged:  
        if word not in stopwords:  
            if word != '\t':  
                if word != '\xa0':
                    if dt_remove(word) ==0:
                        outstr += word 
                        outstr += " "  
    return outstr  
    
text1=jiebaclearText(text)

# %%
text1
# Out:
# '\ufeff 征求 水产 养殖 污染 防治 技术 政策 征求意见 稿 意见 函 环办 函 号 \u3000 \u3000 单位     \u3000 \u3000 贯彻   中华人民共和国 环境保护 法 防治 环境污染 改善 环境质量 我部 决定 制定   水产 养殖 污染 防治 技术 政策 目前 编制 单位 已 完成 文件   征求意见 稿及 编制 说明 现印 送 请 研究 提出 书面 意见 年 月 日前 反馈 我部     \u3000 \u3000 联系人   环境保护部 科技 标准 司 \u3000 刘睿倩     \u3000 \u3000 通信地址 北京市 西城区 西直门 南小街 号     \u3000 \u3000 邮政编码     \u3000 \u3000 联系电话     \u3000 \u3000 传真     \u3000 \u3000 附件 征求意见 单位名单     \u3000 \u3000 水产 养殖 污染 防治 技术 政策 征求意见 稿     \u3000 \u
# ...

# %%
#生成
wc=WordCloud(
    background_color="white",
    max_words=1000000000000000,
    mask=bg,            #设置图片的背景
    max_font_size=100,
    random_state=80,
    font_path='C:/Windows/Fonts/simkai.ttf'   #中文处理，用系统自带的字体
    ).generate(text4)
#为图片设置字体
my_font=fm.FontProperties(fname='C:/Windows/Fonts/simkai.ttf')
#产生背景图片，基于彩色图像的颜色生成器
image_colors=ImageColorGenerator(bg)
#开始画图
plt.imshow(wc.recolor(color_func=image_colors))
#为云图去掉坐标轴
plt.axis("off")
#画云图，显示
plt.figure()
#plt.show()
#为背景图去掉坐标轴
#plt.axis("off")
#plt.imshow(bg,cmap=plt.cm.gray)

#保存云图
wc.to_file("wefeiniaoji.png")

# %%
import pandas as pd

# %%
news=pd.read_csv("C:/Users/Ax/Desktop/111111/test_50_2.csv")

# %%
news
# Out:
#     序号                            title  \
# 0    1                   近期猪价行情或继续小幅下跌！
# 1    2              凉茶深化旺季营销 饮料市场整体增速下滑
# 2    3           科学家：俄罗斯未来100年可以没有转基因食品
# 3    4           俏江南“变脸”内幕：业内称张兰不应该引狼入室
# 4    5               中绿集团向灾区捐赠物资价值120万元
# 5    6               美国爆发的禽流感并未严重冲击豆粕需求
# 6    7           青岛夏粮有望再获丰收 小麦播种同比增18万亩
# 7    8            2015年泰国大米出口量预计为1100万吨
# 8    9         山西汾酒董事长：建议成立“一带一路”中国酒业联盟
# 9   10        猪价年里年外不缺“紧俏” 节前猪价调整空间非常有限
# 10  11          北京猪肉市场供货稳定 五花肉33.45元每公斤
# 11  12                节前食品价格涨势和缓 市场供给充足
# 12  13        2007年6月股市发展环境展望：宏观面有望风平浪静
# 13  14                 酒庄酒乱象难除 价格体系重塑在即
# 14  15           北方多地猪价上涨 猪市继续以高位调整行情为主
# 15  16        麒麟联手柒和伊控股首次开发自有品牌啤酒“醇厚啤酒”
# 16  17               湖北江城猪肉零售价平均下降10%左右
# 17  18                  春节临近 生猪市场转淡行情偏弱
# 18  19        2017年1月22日全国玉米价格最新行情走势及预测
# 19  20            南昌水果批发价普遍上涨 最高上涨幅达50%
# 20  21                  6月初以来全国蔬菜价格降势趋缓
# 21  22                    新税法将重创希腊当地酿酒商
# ...

# %%
news_contents=news.content

# %%
replaces = addwordslist('C:/Users/Ax/Desktop/111111/replaces.txt')

# %%
news_contents_cut=[]
for content in news_contents:
    content_cut=jiebaclearText(content)
    for replace in replaces:
        content_cut=content_cut.replace(replace,'')
        content_cut=content_cut.replace('  ','')
    news_contents_cut.append(content_cut)

# %%
news_contents_cut[0]
# Out:
# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

"""
功能：测试gensim使用，处理中文语料
时间：2016年5月21日 20:49:07
"""

from gensim.models import word2vec
import logging

# 主程序
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
sentences = word2vec.Text8Corpus(u"C:/Users/Ax/Desktop/tqx/关系抽取/compete relation extraction/python文件读取测试/企业相关新闻_50UTF-8.txt")  # 加载语料
model = word2vec.Word2Vec(sentences, size=200)  # 默认window=5

# 计算两个词的相似度/相关程度
y1 = model.similarity(u"科学家", u"生物")
print (u"【不错】和【好】的相似度为：", y1)
print ("--------\n")
# Out:
# 2018-09-05 18:23:01,978 : INFO : collecting all words and their counts
# 2018-09-05 18:23:01,980 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-09-05 18:23:01,981 : INFO : collected 865 word types from a corpus of 885 raw words and 1 sentences
# 2018-09-05 18:23:01,981 : INFO : Loading a fresh vocabulary
# 2018-09-05 18:23:01,982 : INFO : min_count=5 retains 1 unique words (0% of original 865, drops 864)
# 2018-09-05 18:23:01,982 : INFO : min_count=5 leaves 6 word corpus (0% of original 885, drops 879)
# 2018-09-05 18:23:01,982 : INFO : deleting the raw counts dictionary of 865 items
# 2018-09-05 18:23:01,983 : INFO : sample=0.001 downsamples 1 most-common words
# 2018-09-05 18:23:01,983 : INFO : downsampling leaves estimated 0 word corpus (3.3% of prior 6)
# 2018-09-05 18:23:01,983 : INFO : estimated required memory for 1 words and 200 dimensions: 2100 bytes
# 2018-09-05 18:23:01,984 : INFO : resetting layer weights
# ...

# %%
from gensim.models import word2vec
import logging

# 主程序
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
sentences = word2vec.Text8Corpus(u"C:/Users/Ax/Desktop/tqx/关系抽取/compete relation extraction/python文件读取测试/企业相关新闻_50UTF-8.txt")  # 加载语料
model = word2vec.Word2Vec(sentences, size=200)  # 默认window=5
print(sentences)
# Out:
# 2018-09-05 18:24:15,920 : INFO : collecting all words and their counts
# 2018-09-05 18:24:15,922 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-09-05 18:24:15,923 : INFO : collected 865 word types from a corpus of 885 raw words and 1 sentences
# 2018-09-05 18:24:15,923 : INFO : Loading a fresh vocabulary
# 2018-09-05 18:24:15,924 : INFO : min_count=5 retains 1 unique words (0% of original 865, drops 864)
# 2018-09-05 18:24:15,924 : INFO : min_count=5 leaves 6 word corpus (0% of original 885, drops 879)
# 2018-09-05 18:24:15,925 : INFO : deleting the raw counts dictionary of 865 items
# 2018-09-05 18:24:15,925 : INFO : sample=0.001 downsamples 1 most-common words
# 2018-09-05 18:24:15,925 : INFO : downsampling leaves estimated 0 word corpus (3.3% of prior 6)
# 2018-09-05 18:24:15,926 : INFO : estimated required memory for 1 words and 200 dimensions: 2100 bytes
# 2018-09-05 18:24:15,926 : INFO : resetting layer weights
# ...

# %%
# 计算某个词的相关词列表
y2 = model.most_similar(u"书", topn=20)  # 20个最相关的
print (u"和【书】最相关的词有：\n")
for item in y2:
    print (item[0], item[1])
print ("--------\n")

# 寻找对应关系
print (u"书-不错，质量-")
y3 = model.most_similar([u'质量', u'不错'], [u'书'], topn=3)
for item in y3:
    print (item[0], item[1])
print ("--------\n")

# 寻找不合群的词
y4 = model.doesnt_match(u"书 书籍 教材 很".split())
print (u"不合群的词：", y4)
print ("--------\n")

# 保存模型，以便重用
model.save(u"书评.model")
# 对应的加载方式
# model_2 = word2vec.Word2Vec.load("text8.model")

# 以一种C语言可以解析的形式存储词向量
model.save_word2vec_format(u"书评.model.bin", binary=True)
# 对应的加载方式
# model_3 = word2vec.Word2Vec.load_word2vec_format("text8.model.bin", binary=True)

if __name__ == "__main__":
    pass

# %%
import nltk
import gensim
from nltk.corpus import brown    
sentences=[[j.lower() for j in i] for i in brown.sents()] 
sentences
# Out:
# [['the',
#   'fulton',
#   'county',
#   'grand',
#   'jury',
#   'said',
#   'friday',
#   'an',
#   'investigation',
#   'of',
#   "atlanta's",
#   'recent',
#   'primary',
#   'election',
#   'produced',
#   '``',
#   'no',
#   'evidence',
#   "''",
#   'that',
#   'any',
#   'irregularities',
#   'took',
#   'place',
#   '.'],
#  ['the',
#   'jury',
#   'further',
#   'said',
#   'in',
#   'term-end',
#   'presentments',
#   'that',
#   'the',
#   'city',
#   'executive',
#   'committee',
#   ',',
#   'which',
#   'had',
#   'over-all',
#   'charge',
#   'of',
#   'the',
#   'election',
#   ',',
#   '``',
#   'deserves',
#   'the',
#   'praise',
#   'and',
#   'thanks',
#   'of',
#   'the',
#   'city',
#   'of',
#   'atlanta',
#   "''",
#   'for',
#   'the',
#   'manner',
#   'in',
#   'which',
#   'the',
#   'election',
#   'was',
#   'conducted',
#   '.'],
#  ['the',
#   'september-october',
#   'term',
#   'jury',
#   'had',
#   'been',
#   'charged',
#   'by',
#   'fulton',
# ...

# %%
model = gensim.models.Word2Vec(sentences, size=100, window=5, min_count=5)
set(model.wv.vocab.keys()) # 查看模型中所有词汇
# Out:
# 2018-09-05 18:48:26,903 : INFO : collecting all words and their counts
# 2018-09-05 18:48:26,903 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-09-05 18:48:26,933 : INFO : PROGRESS: at sentence #10000, processed 219770 words, keeping 21248 word types
# 2018-09-05 18:48:26,965 : INFO : PROGRESS: at sentence #20000, processed 430477 words, keeping 30743 word types
# 2018-09-05 18:48:27,001 : INFO : PROGRESS: at sentence #30000, processed 669056 words, keeping 37767 word types
# 2018-09-05 18:48:27,036 : INFO : PROGRESS: at sentence #40000, processed 888291 words, keeping 43708 word types
# 2018-09-05 18:48:27,058 : INFO : PROGRESS: at sentence #50000, processed 1039920 words, keeping 47116 word types
# 2018-09-05 18:48:27,077 : INFO : collected 49815 word types from a corpus of 1161192 raw words and 57340 sentences
# 2018-09-05 18:48:27,077 : INFO : Loading a fresh vocabulary
# ...

# %%
model['raining'] # 查看训练得到的词向量
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-0.04734677, -0.01040067, -0.02927513, -0.00051313, -0.03262928,
#        -0.03412501,  0.03276896,  0.01032278,  0.01526122, -0.03575404,
#        -0.00882441,  0.00918284, -0.01253569,  0.00264938,  0.00898665,
#         0.02432135,  0.0046754 , -0.03596606,  0.00478239,  0.00439243,
#        -0.01924167, -0.01400534,  0.03392276,  0.08723559,  0.00992092,
#        -0.06065287, -0.00276757, -0.02803791, -0.05549395,  0.05642426,
#         0.03171108,  0.04828534, -0.0080909 ,  0.01701627,  0.01609855,
#         0.04154511, -0.00476488, -0.06233311,  0.02175075,  0.00404698,
#         0.00276388,  0.05969246, -0.01531711,  0.02365817,  0.11641957,
#        -0.02071807,  0.00888073,  0.00727716,  0.06413349,  0.0283826 ,
# ...

# %% [markdown]
# # gensim

# %%
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import Word2Vec

path = get_tmpfile("word2vec.model")

model = Word2Vec(common_texts, size=100, window=5, min_count=1, workers=4)
model.save("word2vec.model")
# Out:
# 2018-09-05 19:18:03,000 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-09-05 19:18:03,001 : INFO : built Dictionary(12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...) from 9 documents (total 29 corpus positions)
# 2018-09-05 19:18:03,001 : INFO : collecting all words and their counts
# 2018-09-05 19:18:03,002 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-09-05 19:18:03,002 : INFO : collected 12 word types from a corpus of 29 raw words and 9 sentences
# 2018-09-05 19:18:03,002 : INFO : Loading a fresh vocabulary
# 2018-09-05 19:18:03,003 : INFO : min_count=1 retains 12 unique words (100% of original 12, drops 0)
# 2018-09-05 19:18:03,003 : INFO : min_count=1 leaves 29 word corpus (100% of original 29, drops 0)
# 2018-09-05 19:18:03,003 : INFO : deleting the raw counts dictionary of 12 items
# 2018-09-05 19:18:03,004 : INFO : sample=0.001 downsamples 12 most-common words
# ...

# %%
model = Word2Vec.load("word2vec.model")
model.train([["hello", "world", "电脑"]], total_examples=1, epochs=1)
# Out:
# 2018-09-05 19:33:26,982 : INFO : loading Word2Vec object from word2vec.model
# 2018-09-05 19:33:26,983 : INFO : loading wv recursively from word2vec.model.wv.* with mmap=None
# 2018-09-05 19:33:26,983 : INFO : setting ignored attribute vectors_norm to None
# 2018-09-05 19:33:26,984 : INFO : loading vocabulary recursively from word2vec.model.vocabulary.* with mmap=None
# 2018-09-05 19:33:26,984 : INFO : loading trainables recursively from word2vec.model.trainables.* with mmap=None
# 2018-09-05 19:33:26,985 : INFO : setting ignored attribute cum_table to None
# 2018-09-05 19:33:26,985 : INFO : loaded word2vec.model
# 2018-09-05 19:33:26,986 : INFO : training model with 4 workers on 12 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-09-05 19:33:26,989 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-05 19:33:26,990 : INFO : worker thread finished; awaiting finish of 2 more threads
# ...

# %%
vector = model.wv['computer']  # numpy vector of a word

# %%
vector
# Out:
# array([ -3.21049406e-03,   4.44305455e-03,   4.50939959e-04,
#         -7.22033437e-04,   1.54354598e-03,  -3.63657577e-03,
#          8.33828701e-04,  -9.91797657e-04,  -2.34627421e-03,
#          3.58071178e-03,  -3.37922107e-03,   1.04620944e-04,
#         -1.44990874e-04,   2.82139354e-03,   4.67534736e-03,
#         -1.33982638e-03,  -7.76644447e-04,   4.06384189e-03,
#          8.35414510e-04,  -4.01576236e-03,  -3.24060908e-03,
#         -2.40054587e-03,  -1.64457946e-03,  -4.55682678e-03,
#         -1.69068319e-03,   4.96418972e-04,   2.83169007e-04,
#         -5.96651749e-04,  -6.10931485e-04,   1.44407013e-03,
#         -1.56442472e-03,  -2.15849723e-03,   2.07410636e-03,
#         -1.11797533e-03,   7.44962745e-05,  -4.89234086e-03,
#          2.57243845e-03,   4.11963696e-03,   4.80787968e-03,
#         -3.20749194e-03,  -1.44514651e-03,   6.80956640e-04,
#         -2.45396467e-03,  -4.55196714e-03,   2.52103433e-03,
# ...

# %%
from gensim.models import KeyedVectors

path = get_tmpfile("wordvectors.kv")

model.wv.save(path)
wv = KeyedVectors.load("model.wv", mmap='r')
vector = wv['computer']  # numpy vector of a word

# %%
from gensim.models import word2vec
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
model50_text0 = word2vec.Word2Vec.load("C:/Users/Ax/Desktop/tqx/关系抽取/compete relation extraction/med50.model.bin")

# %%
my_dict=dict({})
for idx,key in enumerate(model50_text0.wv.vocab):
    try:
        key.decode('utf-8')
    except:
        my_dict[key]=model50_text0.wv[key]

# %%
my_dict
# Out:
# {'\ufeff': array([-0.58342862, -0.37722802, -0.50767839,  0.58546346, -0.40873379,
#          1.10494828, -0.41989535,  0.48687851, -1.86918068,  0.3069154 ,
#          0.78622389,  1.93962824, -0.04511769,  0.2949799 , -0.10493624,
#          1.6670754 , -0.45226559, -0.32697946,  0.49900827, -0.00261096,
#         -0.34546724, -0.65721554,  0.96050066,  0.38028556,  0.49272189,
#          0.03972011,  0.2736347 ,  1.14743507, -0.21535054, -0.32611123,
#          0.32057595, -0.47041115, -0.2175274 ,  0.63283247, -0.17252111,
#          0.31072727, -1.02616048,  0.46807089, -1.33728659,  0.5155496 ,
#          1.26837289, -0.23313548,  0.252507  ,  0.38143432, -0.05959945,
#          0.83951122, -0.56831229,  0.09967577, -0.14665687, -0.16425319], dtype=float32),
#  'title': array([-3.02743459,  0.20737256,  0.24574199, -2.83491659,  2.70316052,
#          3.32342124, -7.03433943,  3.69190097, -1.49468815,  1.70361495,
# ...

# %%
my_dict['\']

# %%
y='!'

# %%
x=y.encode('utf-8')

# %%
x
# Out:
# b'!'

# %%
x.decode('utf-8')
# Out:
# '!'

# %%
x
# Out:
# b'!'

# %%
x=b'!'

# %%
x
# Out:
# b'!'

# %%
x='我们'
try:
    x.encode('gbk')
    print(1)
except:
    print(2)
# Out:
# 1
